# %%
# %matplotlib inline
import skmob
import pandas as pd
import skmob.measures.individual as ind_measure
import torch
import gpytorch
from gpytorch.kernels import RQKernel as RQ, RBFKernel as SE, \
PeriodicKernel as PER, ScaleKernel, LinearKernel as LIN, MaternKernel as MAT, \
SpectralMixtureKernel as SMK, PiecewisePolynomialKernel as PPK, CylindricalKernel as CYL
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error
from gpytorch.constraints import Interval
import time

# Import intra-package scripts
import utils.helper_func as helper_func
import utils.GP as GP
import mobileDataToolkit.analysis as analysis
import mobileDataToolkit.preprocessing as preprocessing

# %% [markdown]
# # Reading Data

# %%
file_path = "C:\\Users\\ekino\\OneDrive - UW\\GPR\\Data\\all_obs_preprocessed.csv"

d1 = preprocessing.dp_MultiTrip(file_path, 312402)
d1.add_DateTime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27616\3098472357.py in <module>
#       2
#       3 d1 = preprocessing.dp_MultiTrip(file_path, 312402)
# ----> 4 d1.add_DateTime()
#
# c:\users\ekino\cis project big data 2021\git\mobileDataToolkit\preprocessing.py in add_DateTime(self)
#      24         Date_Time = list()
#      25         for i in self.data['unix_start_t']:
# ---> 26             Date_Time.append(datetime.utcfromtimestamp(i).strftime('%Y-%m-%d %H:%M:%S'))
#      27         self.data['Date_Time'] = Date_Time
#      28         self.data['Date_Time'] = pd.to_datetime(self.data['Date_Time'])
#
# AttributeError: module 'datetime' has no attribute 'utcfromtimestamp'
