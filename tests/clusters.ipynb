# %%
#import math
import torch
import gpytorch
import numpy as np
#from sklearn.model_selection import train_test_split
from kneed import KneeLocator
from sklearn.cluster import KMeans
#from sklearn.metrics import silhouette_score
from gpytorch.kernels import RQKernel as RQ, RBFKernel as SE, \
PeriodicKernel as PER, ScaleKernel, LinearKernel as LIN, MaternKernel as MAT, \
SpectralMixtureKernel as SMK, PiecewisePolynomialKernel as PPK, CylindricalKernel as CYL
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
import random
import mobileDataToolkit.preprocessing_v2 as preprocessing
import mobileDataToolkit.analysis as analysis
import mobileDataToolkit.methods as methods
import mobileDataToolkit.metrics as metrics
import utils.GP as GP
import utils.helper_func as helper_func
import geopandas as gpd
import skmob
import skmob.preprocessing.detection
import skmob.preprocessing.clustering
import warnings
warnings.filterwarnings("ignore")

# %%
in_path = "C:/Users/ekino/CIS Project Big Data 2021/Data/newAllTrips_withmetrics.csv"
c_path = "C:/Users/ekino/CIS Project Big Data 2021/Data/newCompressedTrips.csv"
all_path = "C:/Users/ekino/CIS Project Big Data 2021/Data/allobservations_2020.csv"

# %%
# Mobility metrics dataset preprocessing
m_df = pd.read_csv(c_path, header=0)
m_df = m_df.dropna()

# Filter out unreasonable trips
m_df = m_df[(m_df['vel_avg'] < 60) & #no faster than 60 m/s (as the crow flies)
            (m_df['time_total'] < 7200) & # no longer than 2 hours
            (m_df['npoints'] > 4) & # at least 4 points for modeling
            (m_df['StartDay'] == m_df['EndDay']) # start day and end day must be the same
            ]

m_df = m_df[m_df['Id_perc'] != 2141084034]

# %%
feats = m_df[['vel_avg', 'distanceTotal', 'time_total', 'hcr', 'vcr', 'npoints', 'sr']]


def mob_clust(feats = feats):
    kmeans_kwargs = {
        "init": "random",
        "n_init": 10,
        "max_iter": 300,
        "random_state": 42,
    }

    # A list holds the SSE values for each k
    sse = []
    for k in range(1, 11):
        kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
        kmeans.fit(feats)
        sse.append(kmeans.inertia_)
      
    plt.style.use("fivethirtyeight")
    plt.plot(range(1, 11), sse)
    plt.xticks(range(1, 11))
    plt.xlabel("Number of Clusters")
    plt.ylabel("SSE")
    #plt.show()
    
    kl = KneeLocator(
        range(1, 11), sse, curve="convex", direction="decreasing"
    )
    
    kmeans = KMeans(
         init="random",
         n_clusters=kl.elbow,
         n_init=10,
         max_iter=300,
         random_state=42
     )
    
    kmeans.fit(feats)
    
    centers = kmeans.cluster_centers_
    labels = kmeans.labels_
    
    return centers, labels, kmeans

random.seed(10)
centers, labels, kmeans = mob_clust(feats)
m_df['labels'] = labels
m_df = m_df.reset_index()
print(m_df.labels.value_counts())

# Cluster 0 is the fastest average speed, and has the lowest sample size
# Cluster 1 is the slowest average speed, and has the highest sample size
# Cluster 2 is the middle speed, and has the middle amount of samples

# Average speeds are inflated due to distances being "as the crow flies"--real transportation networks are more convoluted
# Out:
# 1    12623
# 2     3639
# 0      929
# Name: labels, dtype: int64

# %%
df = pd.read_csv(in_path, header=0)

trains1 = pd.DataFrame( columns = ['index', 'time', 'day', 'week', 'train_lat', 'train_long', 'trip_ID'])
trains2 = pd.DataFrame( columns = ['index', 'time', 'day', 'week', 'train_lat', 'train_long', 'trip_ID'])
trains3 = pd.DataFrame( columns = ['index', 'time', 'day', 'week', 'train_lat', 'train_long', 'trip_ID'])

tot1 = pd.DataFrame( columns =['trip_ID', 'time', 'day', 'test_lat', 'pred_lat', 'test_long', \
                               'pred_long', 'dist','temp_ocp','prec_train', 'prec_test', 'lengthscale', \
                                   'var_lat', 'var_long', 'noise', 'loss', 'rmse_lat', 'rmse_long']) 
tot2 = pd.DataFrame( columns =['trip_ID', 'time', 'day', 'test_lat', 'pred_lat', 'test_long', \
                               'pred_long', 'dist','temp_ocp','prec_train', 'prec_test', 'lengthscale', \
                                   'var_lat', 'var_long', 'noise', 'loss', 'rmse_lat', 'rmse_long']) 
tot3 = pd.DataFrame( columns =['trip_ID', 'time', 'day', 'test_lat', 'pred_lat', 'test_long', \
                               'pred_long', 'dist','temp_ocp','prec_train', 'prec_test', 'lengthscale', \
                                   'var_lat', 'var_long', 'noise', 'loss', 'rmse_lat', 'rmse_long'])

# %%
trip1 = df[df['trip_ID'] == m_df['Id_perc'][1]].drop_duplicates(subset=['unix_start_t'], keep='first')

# %%
# Find all trips associated with trip 1's user
trips = df[df['user_ID'] == trip1['user_ID'].iloc[0]]
trips.head()
# Out:
#    unix_start_t                                            user_ID   orig_lat  \
# 0    1589533570  016e0ad2a6d6f405a2391c275fd23d44dff6ad50443596...  48.143009
# 1    1589533596  016e0ad2a6d6f405a2391c275fd23d44dff6ad50443596...  48.143263
# 2    1589533670  016e0ad2a6d6f405a2391c275fd23d44dff6ad50443596...  48.137186
# 3    1589533715  016e0ad2a6d6f405a2391c275fd23d44dff6ad50443596...  48.144141
# 4    1589533749  016e0ad2a6d6f405a2391c275fd23d44dff6ad50443596...  48.149366
#
#     orig_long  orig_unc  human_start_t            Date_Time     trip_ID  \
# 0 -122.227877      65.0   2.005150e+11  2020-05-15 09:06:10  2141083201
# 1 -122.226734       8.0   2.005150e+11  2020-05-15 09:06:36  2141083201
# 2 -122.215953       4.0   2.005150e+11  2020-05-15 09:07:50  2141083201
# 3 -122.215554       4.0   2.005150e+11  2020-05-15 09:08:35  2141083201
# 4 -122.215506       4.0   2.005150e+11  2020-05-15 09:09:09  2141083201
#
#       distance        vel  delta_time     angle
# 0     0.000000   0.000000           0  0.000000
# 1    89.626835   3.447186          26  1.249311
# 2  1048.984524  14.175467          74  2.272136
# 3   773.917604  17.198169          45  0.038261
# 4   580.995327  17.088098          34  0.006129

# %%
# %%time
tdf = skmob.TrajDataFrame(trips, latitude='orig_lat', longitude='orig_long', datetime='Date_Time')
f_tdf = skmob.preprocessing.filtering.filter(tdf, max_speed_kmh=400, include_loops=True)
fc_tdf = skmob.preprocessing.compression.compress(f_tdf, spatial_radius_km=0.1) # vary the spatial radius to see how prediction changes
fcs_tdf = skmob.preprocessing.detection.stay_locations(fc_tdf)

n_deleted_points = len(tdf) - len(f_tdf) # number of deleted points during filtering
print("The number of deleted points during filtering is: {}".format(n_deleted_points))

n_deleted_points = len(f_tdf) - len(fc_tdf) # number of deleted points during compression
print("The ratio of deleted points during compression to the number of original points is: {}".format(n_deleted_points / len(trips)))
# Out:
# The number of deleted points during filtering is: 43
# The ratio of deleted points during compression to the number of original points is: 0.26405375139977605
# Wall time: 1 s

# %%
gpd_df = gpd.GeoDataFrame(fc_tdf, geometry=gpd.points_from_xy(fc_tdf.lng, fc_tdf.lat), crs='EPSG:4326')

# %%
gpd_df.plot()
# Out:
# <AxesSubplot:>

# %%
analysis.tempOcp(trip1, 'unix_start_t', bin_len=60*5)
# Out:
# 0.8888888888888888

# %%
tr_df = preprocessing.dp_MultiTrip(data=fc_tdf)
tr_df.Multi_Trip_Preprocess(lat='lat', long='lng', datetime='datetime')
tr_df.data.columns
# Out:
# Index(['index', 'unix_start_t', 'user_ID', 'lat', 'lng', 'orig_unc',
#        'human_start_t', 'datetime', 'trip_ID', 'distance', 'vel', 'delta_time',
#        'angle', 'geometry', 'DoW', 'Year', 'Month', 'Day', 'Week', 'Hour',
#        'WoM', 'norm_lat', 'norm_long', 'SaM', 'Holiday', 'weekend', 'AM_peak',
#        'PM_peak', 'day_0', 'day_1', 'day_2', 'day_3', 'day_4', 'day_5',
#        'day_6', 'week_1', 'week_2', 'week_3', 'week_4', 'week_5'],
#       dtype='object')

# %%
# Move 'unix_start_t' to before 'SaM'
cols = list(tr_df.data.columns)
cols.insert(22, cols.pop(cols.index('unix_start_t')))
tr_df.data = tr_df.data.loc[:, cols]   
tr_df.data.columns
# Out:
# Index(['index', 'user_ID', 'lat', 'lng', 'orig_unc', 'human_start_t',
#        'datetime', 'trip_ID', 'distance', 'vel', 'delta_time', 'angle',
#        'geometry', 'DoW', 'Year', 'Month', 'Day', 'Week', 'Hour', 'WoM',
#        'norm_lat', 'norm_long', 'unix_start_t', 'SaM', 'Holiday', 'weekend',
#        'AM_peak', 'PM_peak', 'day_0', 'day_1', 'day_2', 'day_3', 'day_4',
#        'day_5', 'day_6', 'week_1', 'week_2', 'week_3', 'week_4', 'week_5'],
#       dtype='object')

# %%
tr_df.Multi_Trip_TrainTestSplit(trip1.iloc[0].Date_Time, trip1.iloc[-1].Date_Time, lat='lat', long='lng', datetime='datetime', unix='unix_start_t', inputstart='unix_start_t')

# %% [markdown]
# ### Normalize data

# %%
scaler1 = MinMaxScaler()
scaler2 = MinMaxScaler()
scaler3 = MinMaxScaler()

unix_train = torch.tensor(scaler1.fit_transform(tr_df.X_train[:,0].reshape(-1,1))).float()
secs_train = torch.tensor(scaler2.fit_transform(tr_df.X_train[:,1].reshape(-1,1))).float()
unix_test = torch.tensor(scaler1.transform(tr_df.X_test[:,0].reshape(-1,1))).float()
secs_test = torch.tensor(scaler2.transform(tr_df.X_test[:,1].reshape(-1,1))).float()

X_train = torch.cat([unix_train, secs_train, tr_df.X_train[:, 2::]], -1).float()
X_test = torch.cat([unix_test, secs_test, tr_df.X_test[:, 2::]], -1).float()

y_train = torch.tensor(scaler3.fit_transform(tr_df.y_train)).float()
y_test = torch.tensor(scaler3.transform(tr_df.y_test)).float()

n_dims = X_train.shape[1]

# %%
model = GP.MTGPRegressor(X_train, y_train, ScaleKernel( RQ(ard_num_dims = n_dims) ))

# %%
# %%time
ls, mll = GP.training(model, X_train, y_train)
# Out:
#  50%|████▉     | 99/200 [15:59<16:19,  9.70s/it, Loss=-2.852, noise=0.000101]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# c:\users\ekino\gpsimpute\utils\GP.py in training(model, X_train, y_train, n_epochs, lr, loss_threshold, fix_noise_variance, verbose)
#     171
#     172             output = model(X_train)
# --> 173             loss = -mll(output, y_train)
#     174             if hasattr(model.covar_module.data_covar_module, 'kernels'):
#     175                 with torch.no_grad():
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\module.py in __call__(self, *inputs, **kwargs)
#      28
#      29     def __call__(self, *inputs, **kwargs):
# ---> 30         outputs = self.forward(*inputs, **kwargs)
#      31         if isinstance(outputs, list):
#      32             return [_validate_module_outputs(output) for output in outputs]
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\mlls\exact_marginal_log_likelihood.py in forward(self, function_dist, target, *params)
#      62         # Get the log prob of the marginal distribution
#      63         output = self.likelihood(function_dist, *params)
# ---> 64         res = output.log_prob(target)
#      65         res = self._add_other_terms(res, params)
#      66
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\distributions\multitask_multivariate_normal.py in log_prob(self, value)
#     209             new_shape = value.shape[:-2] + value.shape[:-3:-1]
#     210             value = value.view(new_shape).transpose(-1, -2).contiguous()
# --> 211         return super().log_prob(value.reshape(*value.shape[:-2], -1))
#     212
#     213     @property
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\distributions\multivariate_normal.py in log_prob(self, value)
#     167         # Get log determininant and first part of quadratic form
#     168         covar = covar.evaluate_kernel()
# --> 169         inv_quad, logdet = covar.inv_quad_logdet(inv_quad_rhs=diff.unsqueeze(-1), logdet=True)
#     170
#     171         res = -0.5 * sum([inv_quad, logdet, diff.size(-1) * math.log(2 * math.pi)])
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\lazy\kronecker_product_added_diag_lazy_tensor.py in inv_quad_logdet(self, inv_quad_rhs, logdet, reduce_inv_quad)
#      61         if inv_quad_rhs is not None:
#      62             inv_quad_term, _ = super().inv_quad_logdet(
# ---> 63                 inv_quad_rhs=inv_quad_rhs, logdet=False, reduce_inv_quad=reduce_inv_quad
#      64             )
#      65         else:
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\lazy\lazy_tensor.py in inv_quad_logdet(self, inv_quad_rhs, logdet, reduce_inv_quad)
#    1300             if inv_quad_rhs is None:
#    1301                 raise RuntimeError("Either `inv_quad_rhs` or `logdet` must be specifed.")
# -> 1302             return self.inv_quad(inv_quad_rhs, reduce_inv_quad=reduce_inv_quad), torch.zeros(
#    1303                 [], dtype=self.dtype, device=self.device
#    1304             )
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\lazy\lazy_tensor.py in inv_quad(self, tensor, reduce_inv_quad)
#    1256         args = (tensor.expand(*result_shape[:-2], *tensor.shape[-2:]),) + self.representation()
#    1257         func = InvQuad.apply
# -> 1258         inv_quad_term = func(self.representation_tree(), *args)
#    1259
#    1260         if reduce_inv_quad:
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\functions\_inv_quad.py in forward(ctx, representation_tree, *args)
#      49
#      50         # Perform solves (for inv_quad) and tridiagonalization (for estimating logdet)
# ---> 51         inv_quad_solves = _solve(lazy_tsr, inv_quad_rhs)
#      52         inv_quad_term = (inv_quad_solves * inv_quad_rhs).sum(-2)
#      53
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\functions\_inv_quad.py in _solve(lazy_tsr, rhs)
#      17         with torch.no_grad():
#      18             preconditioner = lazy_tsr.detach()._inv_matmul_preconditioner()
# ---> 19         return lazy_tsr._solve(rhs, preconditioner)
#      20
#      21
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\lazy\kronecker_product_added_diag_lazy_tensor.py in _solve(self, rhs, preconditioner, num_tridiag)
#     187             # https://papers.nips.cc/paper/2013/file/59c33016884a62116be975a9bb8257e3-Paper.pdf
#     188
# --> 189             dlt_inv_root, evals_p_i, evecs = _symmetrize_kpadlt_constructor(lt, dlt)
#     190
#     191             res1 = evecs._transpose_nonbatch().matmul(dlt_inv_root.matmul(rhs))
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\lazy\kronecker_product_added_diag_lazy_tensor.py in _symmetrize_kpadlt_constructor(lt, dlt)
#      37         *[d.matmul(k).matmul(d) for k, d in zip(lt.lazy_tensors, dlt_inv_root.lazy_tensors)]
#      38     )
# ---> 39     evals, evecs = symm_prod.diagonalization()
#      40     evals_plus_i = DiagLazyTensor(evals + 1.0)
#      41
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\lazy\kronecker_product_lazy_tensor.py in diagonalization(self, method)
#     142         if method is None:
#     143             method = "symeig"
# --> 144         return super().diagonalization(method=method)
#     145
#     146     @cached
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\utils\memoize.py in g(self, *args, **kwargs)
#      57         kwargs_pkl = pickle.dumps(kwargs)
#      58         if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 59             return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      60         return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#      61
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\lazy\lazy_tensor.py in diagonalization(self, method)
#    1703
#    1704         elif method == "symeig":
# -> 1705             evals, evecs = self.symeig(eigenvectors=True)
#    1706         else:
#    1707             raise RuntimeError(f"Unknown diagonalization method '{method}'")
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\utils\memoize.py in g(self, *args, **kwargs)
#      57         kwargs_pkl = pickle.dumps(kwargs)
#      58         if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 59             return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      60         return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#      61
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\lazy\lazy_tensor.py in symeig(self, eigenvectors)
#    1975         except CachingError:
#    1976             pass
# -> 1977         return self._symeig(eigenvectors=eigenvectors)
#    1978
#    1979     def to(self, *args, **kwargs):
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\lazy\kronecker_product_lazy_tensor.py in _symeig(self, eigenvectors, return_evals_as_lazy)
#     292         evals, evecs = [], []
#     293         for lt in self.lazy_tensors:
# --> 294             evals_, evecs_ = lt.symeig(eigenvectors=eigenvectors)
#     295             evals.append(evals_)
#     296             evecs.append(evecs_)
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\utils\memoize.py in g(self, *args, **kwargs)
#      57         kwargs_pkl = pickle.dumps(kwargs)
#      58         if not _is_in_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl):
# ---> 59             return _add_to_cache(self, cache_name, method(self, *args, **kwargs), *args, kwargs_pkl=kwargs_pkl)
#      60         return _get_from_cache(self, cache_name, *args, kwargs_pkl=kwargs_pkl)
#      61
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\lazy\lazy_tensor.py in symeig(self, eigenvectors)
#    1975         except CachingError:
#    1976             pass
# -> 1977         return self._symeig(eigenvectors=eigenvectors)
#    1978
#    1979     def to(self, *args, **kwargs):
#
# c:\Users\ekino\.conda\envs\gdal_env\lib\site-packages\gpytorch\lazy\lazy_tensor.py in _symeig(self, eigenvectors)
#    2307         # potentially perform decomposition in double precision for numerical stability
#    2308         dtype = self.dtype
# -> 2309         evals, evecs = torch.linalg.eigh(self.evaluate().to(dtype=settings._linalg_dtype_symeig.value()))
#    2310         # chop any negative eigenvalues.
#    2311         # TODO: warn if evals are significantly negative
#
# KeyboardInterrupt:

# %% [markdown]
# ### Check model parameters

# %%
# Check model parameters
print(model.covar_module.data_covar_module.base_kernel.lengthscale)
print(model.covar_module.data_covar_module.outputscale)
print(model.likelihood.noise)
# Out:
# tensor([[6.9644e-01, 9.7559e-02, 6.9315e-01, 8.2864e-02, 1.6847e-01, 1.4769e+01,
#          8.4660e-01, 1.2664e+01, 5.9668e+00, 1.5088e+01, 1.6185e+01, 1.5818e-01,
#          2.0060e+00, 1.1928e+01, 3.3368e+00, 2.5158e-01, 1.1050e+01, 1.4371e-02]],
#        grad_fn=<SoftplusBackward0>)
# tensor(0.1127, grad_fn=<SoftplusBackward0>)
# tensor([0.0001], grad_fn=<AddBackward0>)

# %%
# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(model.likelihood, model)

with torch.no_grad():
    log_ll = mll(model(X_train), y_train) * X_train.shape[0]
            
N = X_train.shape[0]
m = sum(p.numel() for p in model.hyperparameters())
bic = -2 * log_ll + m * np.log(N)

# %%
predictions, mean = model.predict(X_test)

# %%
model.plot_preds(mean, tr_df.date_train, tr_df.date_test, y_train, y_test)

# %%
metrics.average_eval(pd.Series(y_test[:,0]), pd.Series(y_test[:,1]), pd.Series(mean[:,0]), pd.Series(mean[:,1]))
# Out:
# {'MAE': 0.049949226569720284,
#  'RMSE': 0.05903698059638829,
#  'MAD': 0.043002314705156995,
#  'MAPE': 0.08663438533435548,
#  'MAXAPE': 0.2677905309602603,
#  'TAPE': 3.5520095360870645}
