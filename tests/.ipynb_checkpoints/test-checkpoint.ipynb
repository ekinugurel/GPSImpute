# %%
# %matplotlib inline
#import skmob
import pandas as pd
#import skmob.measures.individual as ind_measure
import torch
import gpytorch
from gpytorch.kernels import RQKernel as RQ, RBFKernel as SE, \
PeriodicKernel as PER, ScaleKernel, LinearKernel as LIN, MaternKernel as MAT, \
SpectralMixtureKernel as SMK, PiecewisePolynomialKernel as PPK, CylindricalKernel as CYL
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error
from gpytorch.constraints import Interval
import time

# Import intra-package scripts
import utils.helper_func as helper_func
import utils.GP as GP
import mobileDataToolkit.analysis as analysis
import mobileDataToolkit.preprocessing as preprocessing

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %% [markdown]
# # Reading Data

# %%
file_path = "C:\\Users\\stlp\\OneDrive - UW\\GPR\\Data\\all_obs_preprocessed.csv"

d1 = preprocessing.dp_MultiTrip(file_path, 8765765)
d1.chooseUser(d1.data.user_ID.unique()[9])

# %% [markdown]
# ## Preprocessing Data: Adding "DateTime" column, subsetting by a timeframe

# %%
d1.add_DateTime()

d1.subsetByTime('01/18/2020 00:00', '02/09/2020 00:00')

data = d1.Multi_Trip_Preprocess()

# %%
d1.mobVisualize(data)

# %%
d1.Multi_Trip_TrainTestSplit('2020-02-05 00:00', '2020-02-06 00:00')

# %%
data[(data['Date_Time'] >= '2020-02-05 00:00') & (data['Date_Time'] < '2020-02-06 00:00')]
# Out:
#       level_0   index  unix_start_t  \
# 1521     1521  122996    1580861134
# 1522     1522  122997    1580861759
# 1523     1523  122998    1580862359
# 1524     1524  122999    1580862960
# 1525     1525  123000    1580863563
# ...       ...     ...           ...
# 1614     1614  123089    1580944248
# 1615     1615  123090    1580944880
# 1616     1616  123091    1580945508
# 1617     1617  123092    1580946108
# 1618     1618  123093    1580946710
#
#                                                 user_ID  mark_1   orig_lat  \
# 1521  016addadda73ffb46e0b0b6c9b365f995437d01470b782...       1  47.903023
# 1522  016addadda73ffb46e0b0b6c9b365f995437d01470b782...       1  47.903023
# 1523  016addadda73ffb46e0b0b6c9b365f995437d01470b782...       1  47.903023
# 1524  016addadda73ffb46e0b0b6c9b365f995437d01470b782...       1  47.903023
# 1525  016addadda73ffb46e0b0b6c9b365f995437d01470b782...       1  47.903023
# ...                                                 ...     ...        ...
# 1614  016addadda73ffb46e0b0b6c9b365f995437d01470b782...       1  47.903023
# 1615  016addadda73ffb46e0b0b6c9b365f995437d01470b782...       1  47.903023
# 1616  016addadda73ffb46e0b0b6c9b365f995437d01470b782...       1  47.903023
# 1617  016addadda73ffb46e0b0b6c9b365f995437d01470b782...       1  47.903023
# 1618  016addadda73ffb46e0b0b6c9b365f995437d01470b782...       1  47.903023
#
#        orig_long  orig_unc  human_start_t           Date_Time  ...  day_4  \
# 1521 -122.225647        16   2.002050e+11 2020-02-05 00:05:34  ...      0
# 1522 -122.225647        16   2.002050e+11 2020-02-05 00:15:59  ...      0
# 1523 -122.225647        16   2.002050e+11 2020-02-05 00:25:59  ...      0
# 1524 -122.225647        17   2.002050e+11 2020-02-05 00:36:00  ...      0
# 1525 -122.225647        17   2.002050e+11 2020-02-05 00:46:03  ...      0
# ...          ...       ...            ...                 ...  ...    ...
# 1614 -122.225647        17   2.002060e+11 2020-02-05 23:10:48  ...      0
# 1615 -122.225647        16   2.002060e+11 2020-02-05 23:21:20  ...      0
# 1616 -122.225647        17   2.002060e+11 2020-02-05 23:31:48  ...      0
# 1617 -122.225647        17   2.002060e+11 2020-02-05 23:41:48  ...      0
# 1618 -122.225647        16   2.002060e+11 2020-02-05 23:51:50  ...      0
#
#       day_5  day_6  week_1  week_2  week_3  week_4 week_5 month_1  month_2
# 1521      0      0       1       0       0       0      0       0        1
# 1522      0      0       1       0       0       0      0       0        1
# 1523      0      0       1       0       0       0      0       0        1
# 1524      0      0       1       0       0       0      0       0        1
# 1525      0      0       1       0       0       0      0       0        1
# ...     ...    ...     ...     ...     ...     ...    ...     ...      ...
# 1614      0      0       1       0       0       0      0       0        1
# 1615      0      0       1       0       0       0      0       0        1
# 1616      0      0       1       0       0       0      0       0        1
# 1617      0      0       1       0       0       0      0       0        1
# 1618      0      0       1       0       0       0      0       0        1
#
# [98 rows x 38 columns]

# %%
data.loc[10]
# Out:
# level_0                                                              10
# index                                                            121485
# unix_start_t                                                 1579314905
# user_ID               016addadda73ffb46e0b0b6c9b365f995437d01470b782...
# mark_1                                                                1
# orig_lat                                                      47.903023
# orig_long                                                   -122.225647
# orig_unc                                                             17
# human_start_t                                            200118000000.0
# Date_Time                                           2020-01-18 02:35:05
# Day of Week                                                           5
# sec_after_midnight                                                 9305
# unix_start_t_min                                                    144
# Year                                                               2020
# Month                                                                 1
# Day                                                                  18
# Week                                                                  3
# norm_lat                                                     0.38143042
# norm_long                                                    0.42410666
# Hour                                                                  2
# Week_of_Month                                                         3
# Holiday                                                               0
# weekend                                                               1
# AM_peak                                                               0
# day_0                                                                 0
# day_1                                                                 0
# day_2                                                                 0
# day_3                                                                 0
# day_4                                                                 0
# day_5                                                                 1
# day_6                                                                 0
# week_1                                                                0
# week_2                                                                0
# week_3                                                                1
# week_4                                                                0
# week_5                                                                0
# month_1                                                               1
# month_2                                                               0
# Name: 10, dtype: object
